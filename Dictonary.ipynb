# %%
#     Indexed
#     Ordered
#     Multiple Values
#     Duplicate Values
#     Mutable

# %%
d = {}
print(type(d))
# Out:
# <class 'dict'>

# %%
# d = {<key>:<value>}

# %%
# Indexed
d = {'a':"Apple"}
print(d)
print(type(d))
# Out:
# {'a': 'Apple'}
# <class 'dict'>

# %%
# Ordered
d = {'a':"Apple",'b':"Ball",'c':"Cat"}
print(d['a'])
print(d['b'])
print(d['c'])
# Out:
# Apple
# Ball
# Cat

# %%
# Multiple Values
d = {'a':"Apple",'b':"Ball",'c':"Cat"}
print(d)
print(len(d))
# Out:
# {'a': 'Apple', 'b': 'Ball', 'c': 'Cat'}
# 3

# %%
# Duplicate Values
d = {'a':"Apple",'b':"Ball",'c':"Apple"}
print(d)
# Out:
# {'a': 'Apple', 'b': 'Ball', 'c': 'Apple'}

# %%
# Mutable
d = {'a':"Apple",'b':"Ball",'a':"Cat"}
print(d)
# Out:
# {'a': 'Cat', 'b': 'Ball'}

# %%
# Mutable
a = {}
a['A'] = "Apple"
a['B'] = "Ball"
a['c'] = "Cat"
a['A'] = "apple"


print(a)
# Out:
# {'A': 'apple', 'B': 'Ball', 'c': 'Cat'}

# %%
a = {}
a['A'] = "Apple"
a['B'] = "Ball"
a['c'] = "Cat"


print(a)
# Out:
# {'A': 'Apple', 'B': 'Ball', 'c': 'Cat'}

# %%
info = dict()
n = int(input("Enter n = "))
for i in range(n):
    name = input("Enter name = ")
    phone = input("Enter phone = ")
    info[name] = phone
print(info)
# Out:
# Enter n = 1
# Enter name = Sangam
# Enter phone = 9824846454
# {'Sangam': '9824846454'}

# %%
{'Sangam': '934732974123', 'sagar': '4734712374'}
for i in d:
    print(i)
# Out:
# a
# b

# %%
d = {'Sangam': '934732974123', 'sagar': '4734712374'}
for i in d.values():
    print(i)
# Out:
# 934732974123
# 4734712374

# %%
l = list()
d = {'Sangam': '934732974123', 'sagar': '4734712374'}
for i in d.items():
    print(i)
# Out:
# ('Sangam', '934732974123')
# ('sagar', '4734712374')

# %%
d = {'Sangam': '934732974123', 'sagar': '4734712374'}
dict(d)
# Out:
# {'Sangam': '934732974123', 'sagar': '4734712374'}

# %%
list("Python")
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
tuple("Python")
# Out:
# ('P', 'y', 't', 'h', 'o', 'n')

# %%
d = {'Sangam': '934732974123', 'sagar': '4734712374'}
d['Sangam'] = '741823744545'
print(d)
# Out:
# {'Sangam': '741823744545', 'sagar': '4734712374'}

# %%
# Mutable
d = {'Sangam': '934732974123', 'sagar': '4734712374'}
d['Hari'] = '741823744545'
print(d)
# Out:
# {'Sangam': '934732974123', 'sagar': '4734712374', 'Hari': '741823744545'}

# %%
# del pop()

# %%
d = {'Sangam': '934732974123', 'sagar': '4734712374'}
del d["Sangam"]
print(d)
# Out:
# {'sagar': '4734712374'}

# %%
d = {'Sangam': '934732974123', 'sagar': '4734712374'}
d.pop("Sangam")
print(d)
# Out:
# {'sagar': '4734712374'}

# %%
# list tuple set dictonary as value
    #  contains following as a values
        #     list
        #     Tuple
        #     Set
        #     Dictonary

# %%
#list inside dict
d = {'Ram': ['9856556543','98564457687'], 
     'Shyam': ['9867665654','9867565545']}
print(d)
print(len(d))
print(type(d))
# Out:
# {'Ram': ['9856556543', '98564457687'], 'Shyam': ['9867665654', '9867565545']}
# 2
# <class 'dict'>

# %%
d = {'Sangam': ['934732974123','9347329741234564'],
     'sagar': ['4734712374','473471237455']}
print(d)
print(len(d))
print(type(d))
# Out:
# {'Sangam': ['934732974123', '9347329741234564'], 'sagar': ['4734712374', '473471237455']}
# 2
# <class 'dict'>

# %%
print(d['Sangam'])
print(d["sagar"][0])
# Out:
# ['934732974123', '9347329741234564']
# 4734712374

# %%
d = {'Sangam': ['934732974123','9347329741234564'],
     'sagar': ['4734712374','473471237455']}
for i in d.items():
    print(i)
# Out:
# ('Sangam', ['934732974123', '9347329741234564'])
# ('sagar', ['4734712374', '473471237455'])

# %%
data = {}
n = int(input("Enter n = "))
for i in range(n):
    name = input("Enter name = ")
    ntc = input("Enter ntc phone no. = ")
    ncell = input("Enter ncell phone no. = ")
    data[name] = [ntc,ncell]
print(data)
# Out:
# Enter n = 1
# Enter name = Sangam
# Enter ntc phone no. = 9862729316
# Enter ncell phone no. = 9824846454
# {'Sangam': ['9862729316', '9824846454']}

# %%
d = {'Sangam': ['934732974123','9347329741234564'],
     'sagar': ['4734712374','473471237455']}
d['Sangam'][0] = 98364636434
del d['sagar'][0]
d
# Out:
# {'Sangam': [98364636434, '9347329741234564'], 'sagar': ['473471237455']}

# %%
d = {'Sangam': ['934732974123','9347329741234564'],
     'sagar': ['4734712374','473471237455']}
d.pop('Sangam')
d
# Out:
# {'sagar': ['4734712374', '473471237455']}

# %%
d = {'Sangam': ['934732974123','9347329741234564'],
     'sagar': ['4734712374','473471237455']}
d['Sangam'].pop(0)
d
# Out:
# {'Sangam': ['9347329741234564'], 'sagar': ['4734712374', '473471237455']}

# %%
d = {'Sangam': ['934732974123','9347329741234564'],
     'sagar': ['4734712374','473471237455']}
d['Sangam'].append("9824392754231794")
d
# Out:
# {'Sangam': ['934732974123', '9347329741234564', '9824392754231794'],
#  'sagar': ['4734712374', '473471237455']}

# %%
# dict inside list
l = [{'Name':'Ram','NTC':9867554543,'NCELL':9808556543},
    {'Name':'Shyam','NTC':9864334321,'NCELL':9808998976}]
print(l)
print(type(l))
print(l[1]['Name'])
# Out:
# [{'Name': 'Ram', 'NTC': 9867554543, 'NCELL': 9808556543}, {'Name': 'Shyam', 'NTC': 9864334321, 'NCELL': 9808998976}]
# <class 'list'>
# Shyam

# %%
mylist = {'mydict': [{'A': 'Letter A'}, {'B': 'Letter C'}, {'C': 'Letter C'}]}
print(mylist['mydict'][0]['A'])
# Out:
# Letter A

# %%
for i in l:
    print(i)
# Out:
# {'Name': 'Ram', 'NTC': 9867554543, 'NCELL': 9808556543}
# {'Name': 'Shyam', 'NTC': 9864334321, 'NCELL': 9808998976}

# %%
data = []
n = int(input('Enter n = '))
for i in range(n):
    name = input("Enter name = ")
    ntc = input("Enter ntc phone = ")
    ncell = input("Enter ncellphone = ")
    info = {'Name':name,'Ntc':ntc,'Ncell':ncell}
    data.append(info)
print(data)
# Out:
# Enter n = 1
# Enter name = Sangam
# Enter ntc phone = 9862729316
# Enter ncellphone = 9824846454
# [{'Name': 'Sangam', 'Ntc': '9862729316', 'Ncell': '9824846454'}]

# %%
print(data[0]['Name'])
# Out:
# Sangam

# %%
data[0]['Name'] = 'Ram'
print(data)
# Out:
# [{'Name': 'Ram', 'Ntc': '9862729316', 'Ncell': '9824846454'}]

# %%
data[0]['Land'] = 34334234
data
# Out:
# [{'Name': 'Ram', 'Ntc': '9862729316', 'Ncell': '9824846454', 'Land': 34334234}]

# %%
# dict inside dict
    # d = {<key>:{<key>:<value>}}

# %%
d = {'Nepal':{'Name':'Ram','NTC':'93473847394','NCELL':'984734343343'},
    'USA':{'Name': 'Ram','NTC':'3934834','NCELL':'384394734'}}
print(d['Nepal'])
# Out:
# {'Name': 'Ram', 'NTC': '93473847394', 'NCELL': '984734343343'}

# %%
print(d['Nepal']['Name'])
# Out:
# Ram

# %%
data = {}
n = int(input('Enter n = '))
for i in range(1,n+1):
    name = input("Enter name = ")
    ntc = input("Enter ntc phone = ")
    ncell = input("Enter ncell phone = ")
    data[i] = {'Name':name,'NTC':ntc,'NCELL':ncell}
    
print(data)
# Out:
# Enter n = 1
# Enter name = Sangam
# Enter ntc phone = 9862729316
# Enter ncell phone = 9824846454
# {1: {'Name': 'Sangam', 'NTC': '9862729316', 'NCELL': '9824846454'}}

# %%
data[3] = {'Name':'Hari','NTC':9867665643,'NCELL':9808556543}
data
# Out:
# {1: {'Name': 'Sangam', 'NTC': '9862729316', 'NCELL': '9824846454'},
#  3: {'Name': 'Hari', 'NTC': 9867665643, 'NCELL': 9808556543}}

# %%
data[1]['Name'] = "Rama"
data
# Out:
# {1: {'Name': 'Rama', 'NTC': '9862729316', 'NCELL': '9824846454'},
#  3: {'Name': 'Hari', 'NTC': 9867665643, 'NCELL': 9808556543}}

# %%
data[1]['NTC'] = [9867665654,98454432]
data
# Out:
# {1: {'Name': 'Rama', 'NTC': [9867665654, 98454432], 'NCELL': '9824846454'},
#  3: {'Name': 'Hari', 'NTC': 9867665643, 'NCELL': 9808556543}}

# %%
d = {('Ram','Shyam'):'Kathmandu'}
print(d)
# Out:
# {('Ram', 'Shyam'): 'Kathmandu'}

# %%
d[('Ram', 'Shyam')]
# Out:
# 'Kathmandu'

# %%
data = []
d = {('Ram','Shyam'):'Kathmandu',('Hari','Sita'):'Patan'}
for i in d.items():
    if "Ram" in i[0]:
        print(i)
# Out:
# (('Ram', 'Shyam'), 'Kathmandu')

# %%
d = {1:{'Name':'Aakash','Physics':{'Th':60,'Pr':20}},
     2:{'Name':'sagar','Physics':{'Th':50,'Pr':10}}}
d
# Out:
# {1: {'Name': 'Aakash', 'Physics': {'Th': 60, 'Pr': 20}},
#  2: {'Name': 'sagar', 'Physics': {'Th': 50, 'Pr': 10}}}

# %%
data = {}
n = int(input('Enter n = '))
for i in range(1,n+1):
    name = input("Enter name = ")
    PhysicsTh = input("Enter physics theory  mark = ")
    PhysicsPr = input("Enter physics paractical  mark = ")
    data[i] = {'Name':name,'PhysicsTh':PhysicsTh,'PhysicsPr':PhysicsPr} 
print(data)
# Out:
# Enter n = 1
# Enter name = Sangam
# Enter physics theory  mark = 78
# Enter physics paractical  mark = 49
# {1: {'Name': 'Sangam', 'PhysicsTh': '78', 'PhysicsPr': '49'}}
