# %%
a = "Hello World"
print(type(a))
print(a)
# Out:
# <class 'str'>
# Hello World

# %%
a = input("Enter a = ")
print(type(a))
# Out:
# Enter a = 10
# <class 'str'>

# %%
a = "Hello"
b = "World"
c = a+b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello World\n"
print(a*2)
# Out:
# Hello World
# Hello World

# %%
a = 'Hello World'
for i in a:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
a = "Hello World"
print(a[3])
# Out:
# l

# %%
a = "Hello World"
print(a[1:5])
# Out:
# ello

# %%
a = "Hello world"
print(a[0:10:2])
# Out:
# Hlowr

# %%
a = "am"
l = len(a)-1
a[l]
# Out:
# 'm'

# %%
a = 'Hello World'
l = len(a)
for i in range(l):
    print(i,a[i])
# Out:
# 0 H
# 1 e
# 2 l
# 3 l
# 4 o
# 5
# 6 W
# 7 o
# 8 r
# 9 l
# 10 d

# %%
# string formating
s = ""
n = int(input('Enter n = '))
for i in range(n):
    name = input("Enter name = ")
    phone = int(input("Enter phone = "))
    info = f"{name} {phone}\n"
    s = s+info
print(s)
# Out:
# Enter n = 2
# Enter name = Ram
# Enter phone = 9483483
# Enter name = shyam
# Enter phone = 3434342
# Ram 9483483
# shyam 3434342

# %%
name = "Ram"
phone = 984343433
info = f"Hello world I am {name}. My contact is {phone}"
print(info)
# Out:
# Hello world I am Ram. My contact is 984343433

# %%
# replace()
# search()
# uppercase()
# lowercase()
