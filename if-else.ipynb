# %%
# if <condition>
#     <operations>
# elif <condition>
#     <operatipns>
# else:
#     <operation>

# %%
# <> <= >= == !=
# and or not
# True/false

# %%
a = int(input('Enter a = '))
b = int(input("Enter b = "))
if a<b:
    print("B is greater")
elif b<a:
    print("A is greater")
else:
    print("Both are eaual")
# Out:
# Enter a = 10
# Enter b = 20
# B is greater

# %%
a = int(input("Enter a = "))
if a % 2 == 0:
        print(a,"is even")
else:
        print(a,"is odd")
# Out:
# Enter a = 11
# 11 is odd

# %%
a = int(input("Enter a = "))
b = int(input("Enter b = "))
o = input("Enter operator")
if o == "+":
    print(a+b)
elif 0 == "-":
    print(a-b)
elif 0 == "*":
    print(a*b)
elif o == "/":
    print(a/b)
else:
    print("Invalid Input")
# Out:
# Enter a = 10
# Enter b = 0
# Enter operator/
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8260/3540797409.py in <module>
#       9     print(a*b)
#      10 elif o == "/":
# ---> 11     print(a/b)
#      12 else:
#      13     print("Invalid Input")
#
# ZeroDivisionError: division by zero

# %%
if <condition>:
    # if <condition>
    #     <operations>
    # elif <condition>
    #     <operatipns>
    # else:
    #     <operation>

# %%
a = int(input("Enter a = "))
b = int(input("Enter b = "))
o = input("Enter oprator")
if 0 == "+":
    print(a+b)
elif o == "-":
    print(a-b)
elif o == "*":
    print(a*b)
elif o == "/":
    if b != 0:
        print(a/b)
    else:
        print("The value of b cannot be zero")
else:
    print("Invalid input")
# Out:
# Enter a = 10
# Enter b = 0
# Enter oprator/
# The value of b cannot be zero
