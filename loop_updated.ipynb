# %%
# WAP to calculate factorial of anumber
# WAP to calculate total amount of a bill

# %%
# WAP to calculate total amount of a bill
# sum of n value

# %%
all_total = 0
s = ""
n = int(input("Enter n = "))
for i in range(n):
    product = input("Enter name = ")
    price = int(input("Enter price = "))
    quantity = int(input("Enter quantity"))
    total = price*quantity
    s = s+product+" "+str(price)+ " "+ str(quantity) +str(total) + "\n"
    all_total = all_total+total
    print("The bill is = \n",s)
    print("All total = ",all_total)

# %%
while Ture:
    print("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8488/1038789065.py in <module>
# ----> 1 while Ture:
#       2     print("Hello World")
#
# NameError: name 'Ture' is not defined

# %%
a = 0
while a<=5:
    print(a,"Hello World")
    a = a+1
# Out:
# 0 Hello World
# 1 Hello World
# 2 Hello World
# 3 Hello World
# 4 Hello World
# 5 Hello World

# %%
a = 5
while a>=0:
    print(a,"Hello World")
    a = a-1
# Out:
# 5 Hello World
# 4 Hello World
# 3 Hello World
# 2 Hello World
# 1 Hello World
# 0 Hello World

# %%
i = 1
x = int(input("Enter x = "))
while i<10:
    print(x,"*",i,"=",x*i)
    i = i+1
# Out:
# Enter x = 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45

# %%
# sum of numbers
s = 0
i = 0
n = int(input("Enter n = "))
while i<n:
    x = int(input("Enter x = "))
    s = s+x
    i = i+1
    print(s)
# Out:
# Enter n = 2
# Enter x = 234
# 234
# Enter x = 23
# 257

# %%
# sum of n nmubers
s = ""
i = 0
n = int(input("Enter n = "))
while i<n:
    x = input("Enter x = ")
    s = s+x+" "
    i = i+1 #range(i,n,1)
    print(s)
# Out:
# Enter n = 2
# Enter x = Ram
# Ram
# Enter x = Shyam
# Ram Shyam

# %%
a = "Python" #range
for i in a:
    print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
a = "Python" #range
for i in a:
    print(i)
# Out:
# P
# y
# t
# h
# o
# n

# %%
a = "Hello World"    #range
for i in a:
    if (i != "l") and (i!=" "):
        print(i)
# Out:
# H
# e
# o
# W
# o
# r
# d

# %%
# control statements
# break
# continue
# pass

# %%
for i in range(5):
    if i ==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i ==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
for i in range(5):
    pass

# %%
a = "Hello World"
for i in a:
    if i == " ":
        continue
    print(i,end = "")
# Out:
# HelloWorld

# %%
a = "Hello World"
for i in a:
    if i ==" ":
        break
    print(i,end = "")
# Out:
# Hello
